# %% [markdown]
# # HR Analytics Project- Understanding the Attrition in HR

# %% [markdown]
# Data Description.

# %% [raw]
# High attrition is problematic for any company. The task is to check whether the employee can be Retention or Attrition with the provided input variables like. The target variable contains Yes or NO variables. So we apply various classification models.

# %% [markdown]
# Importing Required Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the data set.

# %%
df=pd.read_csv('HRAttrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.shape #checking data dimensions.
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Checking Null Values.

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [raw]
# We can see that there are no null values in our data.

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [raw]
# Checking for categorical data and repeating values in the data.

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
df['NumCompaniesWorked'].value_counts(ascending=True)
# Out:
# 8     49
# 9     52
# 5     63
# 6     70
# 7     74
# 4    139
# 2    146
# 3    159
# 0    197
# 1    521
# Name: NumCompaniesWorked, dtype: int64

# %%
df['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
df['PerformanceRating'].value_counts()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %%
df['RelationshipSatisfaction'].value_counts()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %% [markdown]
# Analysis

# %%
import matplotlib.pyplot as plt
df['Attrition'].hist(grid=True)
plt.show()
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [raw]
# The data set contains 1233 employees with no attriton and 237 are with yes attrition.

# %% [raw]
# Now we will divide categorical columns and numerical columns for analysis purposes. Also, we will remove 'EmployeeCount','EmployeeNumber','Over18','StandardHours' columns because these are irrelevant data.

# %%
df.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age', hue='Attrition', data = df)

# %% [raw]
# The highest count of employee attrition is with employees who are having age 29 & 31. The age with the highest retention is age 34 & 35.

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Gender', hue='Attrition', data = df) 
plt.show()

# %%
k=df.drop('Attrition',axis=1)
f=df['Attrition']

# %%
k=['Department','EducationField','JobRole','MaritalStatus','NumCompaniesWorked','OverTime','Gender','PerformanceRating','RelationshipSatisfaction']
for m in k:
    sns.countplot(x=m,hue='Attrition',data=df)
    print(df[m].value_counts())
    plt.show()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# Male      882
# Female    588
# ...

# %% [raw]
# We can see that high attrition is with people:
#   * From Reasearch and Development department
#   * With LifeScience education field
#   *People who are single
#   *People who worked in one company and
#   *Gender: Male
#   *People who are having performance rating of 3

# %% [markdown]
# checking for skewness and Outliers.

# %%
for i in df.describe().columns:
    sns.distplot(df[i].dropna())
    plt.show()

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
for i in df.describe().columns:
    sns.boxplot(df[i].dropna())
    plt.show()

# %% [raw]
# We can see that there are skewness and outliers in the given data set in some columns but the target variable attrition has two values whether yes or no and there is a lot of inbalnce in the target variable and all the columns are showing relationship to the target variable. So, we are not going to remove outliers.

# %% [raw]
# We need Numerical data to train the model. So we will change the required categorical data into numerical data by the encoding process.

# %% [markdown]
# Encoding Process

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Attrition']=le.fit_transform(df['Attrition'])
df['Department']=le.fit_transform(df['Department'])
df['EducationField']=le.fit_transform(df['EducationField'])
df['JobRole']=le.fit_transform(df['JobRole'])
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])
df['OverTime']=le.fit_transform(df['OverTime'])
df['Gender']=le.fit_transform(df['Gender'])
df['BusinessTravel']=le.fit_transform(df['BusinessTravel'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int32
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   int32
# ...

# %% [markdown]
# Splitting the data.

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %% [markdown]
# Checking for best Random state.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxAcc=0
maxRS=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print('best random state:',maxAcc,'on random state:',maxRS)
# Out:
# best random state: 0.8945578231292517 on random state: 26

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
dr=DecisionTreeClassifier()
svc=SVC()
rf=RandomForestClassifier()

# %%
model=[lr,dr,svc,rf]

# %%
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print('accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# accuracy score of LogisticRegression() is:
# 0.8571428571428571
# [[249   0]
#  [ 42   3]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       249
#            1       1.00      0.07      0.12        45
#
#     accuracy                           0.86       294
#    macro avg       0.93      0.53      0.52       294
# weighted avg       0.88      0.86      0.80       294
#
#
#
# accuracy score of DecisionTreeClassifier() is:
# 0.7959183673469388
# [[218  31]
#  [ 29  16]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       249
#            1       0.34      0.36      0.35        45
#
#     accuracy                           0.80       294
#    macro avg       0.61      0.62      0.61       294
# weighted avg       0.80      0.80      0.80       294
#
#
#
# accuracy score of SVC() is:
# 0.8469387755102041
# [[249   0]
#  [ 45   0]]
# ...

# %% [raw]
# We are getting the highest accuracy with Logistic Regression and Random Forest classifier (85%), but the f1 score is not good. DecisionTreeClassifier provides 78% accuracy but better f1 score. So, we will do cross-validation and Hyper tuning.  so we will check cross-validation scores

# %% [markdown]
# Cross_validation

# %%
from sklearn.model_selection import cross_val_score
drs=cross_val_score(dr,x,y,cv=5)
print('cross validation of DecisionTreeClassiffier:',drs.mean())
# Out:
# cross validation of DecisionTreeClassiffier: 0.7870748299319728

# %%
Lrs=cross_val_score(lr,x,y,cv=5)
print('cross validation of LogisticRegression:',Lrs.mean())
# Out:
# cross validation of LogisticRegression: 0.8421768707482993

# %%
svr=cross_val_score(svc,x,y,cv=5)
print('cross validation of SVM:',svr.mean())
# Out:
# cross validation of SVM: 0.8387755102040817

# %%
rfr=cross_val_score(rf,x,y,cv=5)
print('cross valdation of RandomForestClassifier:',rfr.mean())
# Out:
# cross valdation of RandomForestClassifier: 0.8591836734693876

# %% [raw]
# We can see that RandomForestClassifier is working good. We will do Hypertuning now to get better metrics also.

# %% [markdown]
# Hyper Parameter Tuning.

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['gini','entropy']}
gd=GridSearchCV(estimator=rf,param_grid=grid_param,scoring='accuracy',cv=5)
gd.fit(x,y)
best_parameter=gd.best_params_
print('best_parameter:',best_parameter)
# Out:
# best_parameter: {'criterion': 'entropy'}

# %%
gd_pred=gd.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,gd_pred)
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,gd_pred))
print(classification_report(y_test,gd_pred))
# Out:
# [[249   0]
#  [  0  45]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       249
#            1       1.00      1.00      1.00        45
#
#     accuracy                           1.00       294
#    macro avg       1.00      1.00      1.00       294
# weighted avg       1.00      1.00      1.00       294

# %% [raw]
# Now we can see that 100% accuracy with f1 score 1. This is the best model. Let's save it.

# %% [markdown]
# Saving the Best Model.

# %%
import joblib
joblib.dump(gd.best_estimator_,'HR_attrition.pkl')
# Out:
# ['HR_attrition.pkl']
